# %%
import os
import pandas as pd

metadata = pd.read_csv('/Users/mervetekgurler/Desktop/PhD/UCB Digital Humanities Summer 2025/DIGHUM101-2025/unesco/proceedings_curation/data/metadata_index.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[2], line 4
#       1 import os
#       2 import pandas as pd
# ----> 4 metadata = pd.read_csv('/Users/mervetekgurler/Desktop/PhD/UCB Digital Humanities Summer 2025/DIGHUM101-2025/unesco/proceedings_curation/data/metadata_index.csv')
#
# ...
